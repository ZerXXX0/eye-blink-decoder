# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Q1flzyg1J8Z2OMweLXf3")
project = rf.workspace("weapon-mpr3p").project("blinkblink")
version = project.version(4)
dataset = version.download("folder")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

modeln = YOLO("yolo26s-cls.pt")
modeln.train(
    data=dataset.location,
    epochs=100,
    imgsz=224,
    batch=32,
    workers=0,        
    name="small_100"
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26s-cls.pt to 'yolo26s-cls.pt': 100% ━━━━━━━━━━━━ 13.0MB 46.9MB/s 0.3s.2s<0.1s
# Ultralytics 8.4.7  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Gojiii\blink blink\repo\eye-blink-decoder\blinkblink-4, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=small_100, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Gojiii\blink blink\repo\eye-blink-decoder\runs\classify\small_100, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# train: C:\Gojiii\blink blink\repo\eye-blink-decoder\blinkblink-4\train... found 1025 images in 2 classes
# val: C:\Gojiii\blink blink\repo\eye-blink-decoder\blinkblink-4\valid... found 252 images in 2 classes
# test: None...
# Overriding model.yaml nc=1000 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    660482  ultralytics.nn.modules.head.Classify         [512, 2]
# YOLO26s-cls summary: 86 layers, 5,445,570 parameters, 5,445,570 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 253.659.1 MB/s, size: 25.8 KB)
# train: Scanning C:\Gojiii\blink blink\repo\eye-blink-decoder\blinkblink-4\train... 1025 images, 0 corrupt: 100% ━━━━━━━━━━━━ 1025/1025  0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 246.662.2 MB/s, size: 25.9 KB)
# val: Scanning C:\Gojiii\blink blink\repo\eye-blink-decoder\blinkblink-4\valid... 252 images, 0 corrupt: 100% ━━━━━━━━━━━━ 252/252  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.001667, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to C:\Gojiii\blink blink\repo\eye-blink-decoder\runs\classify\small_100
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/100     0.762G      0.663          1        224: 100% ━━━━━━━━━━━━ 33/33 3.1it/s 10.6s0.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.1it/s 1.3s0.5s
#                    all      0.603          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#
1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      75/100      1.21G    0.03775          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      76/100      1.21G    0.03559          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      77/100      1.21G     0.0439          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.2s0.4s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      78/100      1.21G    0.03153          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s0.4s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      79/100      1.21G    0.03766          1        224: 100% ━━━━━━━━━━━━ 33/33 4.0it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      80/100      1.21G     0.0364          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      81/100      1.21G    0.08575          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.5s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      82/100      1.21G    0.03129          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.2it/s 1.2s0.5s
#                    all      0.984          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      83/100      1.21G    0.03414          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      84/100      1.21G     0.0581          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      85/100      1.21G     0.0472          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      86/100      1.21G    0.02912          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.3it/s 1.2s0.5s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      87/100      1.21G    0.03576          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      88/100      1.21G    0.06165          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      89/100      1.21G    0.03277          1        224: 100% ━━━━━━━━━━━━ 33/33 3.8it/s 8.6s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      90/100      1.21G    0.02591          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      91/100      1.21G     0.0444          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      92/100      1.21G    0.03627          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      93/100      1.21G    0.04687          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.4it/s 1.2s0.5s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      94/100      1.21G     0.0345          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.5it/s 1.1s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      95/100      1.21G     0.0404          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      96/100      1.21G    0.03039          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      97/100      1.21G    0.02452          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.4s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.6it/s 1.1s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      98/100      1.21G    0.03074          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all       0.98          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#      99/100      1.21G    0.03581          1        224: 100% ━━━━━━━━━━━━ 33/33 3.9it/s 8.5s0.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all      0.976          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#     100/100      1.21G    0.03513          1        224: 100% ━━━━━━━━━━━━ 33/33 3.8it/s 8.6s0.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.7it/s 1.1s0.4s
#                    all       0.98          1
#
# 100 epochs completed in 0.275 hours.
# Optimizer stripped from C:\Gojiii\blink blink\repo\eye-blink-decoder\runs\classify\small_100\weights\last.pt, 11.0MB
# Optimizer stripped from C:\Gojiii\blink blink\repo\eye-blink-decoder\runs\classify\small_100\weights\best.pt, 11.0MB
#
# Validating C:\Gojiii\blink blink\repo\eye-blink-decoder\runs\classify\small_100\weights\best.pt...
# Ultralytics 8.4.7  Python-3.9.22 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5070 Ti, 16303MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,436,690 parameters, 0 gradients, 12.0 GFLOPs
# train: C:\Gojiii\blink blink\repo\eye-blink-decoder\blinkblink-4\train... found 1025 images in 2 classes
# val: C:\Gojiii\blink blink\repo\eye-blink-decoder\blinkblink-4\valid... found 252 images in 2 classes
# test: None...
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 4/4 3.0it/s 1.3s0.5s
#                    all      0.992          1
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to C:\Gojiii\blink blink\repo\eye-blink-decoder\runs\classify\small_100
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x00000248FC83FD90>
# curves: []
# curves_results: []
# fitness: 0.9960317313671112
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.9920634627342224, 'metrics/accuracy_top5': 1.0, 'fitness': 0.9960317313671112}
# save_dir: WindowsPath('C:/Gojiii/blink blink/repo/eye-blink-decoder/runs/classify/small_100')
# speed: {'preprocess': 0.13065357142798867, 'inference': 0.65294126984094, 'loss': 0.00016031746072474648, 'postprocess': 0.0003285714289148249}
# task: 'classify'
# top1: 0.9920634627342224
# top5: 1.0
