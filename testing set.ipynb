# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Q1flzyg1J8Z2OMweLXf3")
project = rf.workspace("weapon-mpr3p").project("blinkblink")
version = project.version(5)
dataset = version.download("folder")
# Out:
# Requirement already satisfied: roboflow in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.9)
# Requirement already satisfied: certifi in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (3.10.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.2.6)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (10.2.0)
# Requirement already satisfied: pi-heif<2 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from roboflow) (1.2.0)
# Collecting Pillow>=7.1.2 (from roboflow)
#   Using cached pillow-12.1.1-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: colorama in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (4.56.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zerx\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->roboflow) (3.4.0)
# Using cached pillow-12.1.1-cp311-cp311-win_amd64.whl (7.0 MB)
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 10.2.0
#     Uninstalling pillow-10.2.0:
#       Successfully uninstalled pillow-10.2.0
# Successfully installed Pillow-12.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# moviepy 2.2.1 requires pillow<12.0,>=9.2.0, but you have pillow 12.1.1 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\ZerX\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
from sklearn.metrics import classification_report
import os
from pathlib import Path

model = YOLO(r"runs\classify\nano_100\weights\best.pt")

test_path = Path(dataset.location) / "test"

y_true = []
y_pred = []

# Loop over class folders
for class_id, class_name in enumerate(sorted(os.listdir(test_path))):
    class_folder = test_path / class_name
    
    for img_path in class_folder.glob("*.*"):
        result = model(img_path, verbose=False)[0]
        
        pred_class = result.probs.top1  # predicted index
        
        y_pred.append(pred_class)
        y_true.append(class_id)

# Print metrics
print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.7000    0.7568    0.7273        37
#            1     0.9769    0.9694    0.9731       392
#
#     accuracy                         0.9510       429
#    macro avg     0.8384    0.8631    0.8502       429
# weighted avg     0.9530    0.9510    0.9519       429

# %%
from ultralytics import YOLO
from sklearn.metrics import classification_report
import os
from pathlib import Path

model = YOLO(r"runs\classify\small_100\weights\best.pt")

test_path = Path(dataset.location) / "test"

y_true = []
y_pred = []

# Loop over class folders
for class_id, class_name in enumerate(sorted(os.listdir(test_path))):
    class_folder = test_path / class_name
    
    for img_path in class_folder.glob("*.*"):
        result = model(img_path, verbose=False)[0]
        
        pred_class = result.probs.top1  # predicted index
        
        y_pred.append(pred_class)
        y_true.append(class_id)

# Print metrics
print(classification_report(y_true, y_pred, digits=4))

# %%
from ultralytics import YOLO
from sklearn.metrics import classification_report
import os
from pathlib import Path

model = YOLO(r"runs\classify\medium_100\weights\best.pt")

test_path = Path(dataset.location) / "test"

y_true = []
y_pred = []

# Loop over class folders
for class_id, class_name in enumerate(sorted(os.listdir(test_path))):
    class_folder = test_path / class_name
    
    for img_path in class_folder.glob("*.*"):
        result = model(img_path, verbose=False)[0]
        
        pred_class = result.probs.top1  # predicted index
        
        y_pred.append(pred_class)
        y_true.append(class_id)

# Print metrics
print(classification_report(y_true, y_pred, digits=4))
