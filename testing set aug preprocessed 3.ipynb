# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Q1flzyg1J8Z2OMweLXf3")
project = rf.workspace("weapon-mpr3p").project("blinkblink")
version = project.version(9)
dataset = version.download("folder")
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
from sklearn.metrics import classification_report
import os
from pathlib import Path

model = YOLO(r"runs\classify\nano_100_aug_preprocessed3\weights\best.pt")

test_path = Path(dataset.location) / "test"

y_true = []
y_pred = []

# Loop over class folders
for class_id, class_name in enumerate(sorted(os.listdir(test_path))):
    class_folder = test_path / class_name
    
    for img_path in class_folder.glob("*.*"):
        result = model(img_path, verbose=False)[0]
        
        pred_class = result.probs.top1  # predicted index
        
        y_pred.append(pred_class)
        y_true.append(class_id)

# Print metrics
print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5246    0.8649    0.6531        37
#            1     0.9864    0.9260    0.9553       392
#
#     accuracy                         0.9207       429
#    macro avg     0.7555    0.8954    0.8042       429
# weighted avg     0.9466    0.9207    0.9292       429

# %%
from ultralytics import YOLO
from sklearn.metrics import classification_report
import os
from pathlib import Path

model = YOLO(r"runs\classify\small_100_aug_preprocessed3\weights\best.pt")

test_path = Path(dataset.location) / "test"

y_true = []
y_pred = []

# Loop over class folders
for class_id, class_name in enumerate(sorted(os.listdir(test_path))):
    class_folder = test_path / class_name
    
    for img_path in class_folder.glob("*.*"):
        result = model(img_path, verbose=False)[0]
        
        pred_class = result.probs.top1  # predicted index
        
        y_pred.append(pred_class)
        y_true.append(class_id)

# Print metrics
print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.3902    0.8649    0.5378        37
#            1     0.9856    0.8724    0.9256       392
#
#     accuracy                         0.8718       429
#    macro avg     0.6879    0.8687    0.7317       429
# weighted avg     0.9342    0.8718    0.8921       429

# %%
from ultralytics import YOLO
from sklearn.metrics import classification_report
import os
from pathlib import Path

model = YOLO(r"runs\classify\medium_100_aug_preprocessed3\weights\best.pt")

test_path = Path(dataset.location) / "test"

y_true = []
y_pred = []

# Loop over class folders
for class_id, class_name in enumerate(sorted(os.listdir(test_path))):
    class_folder = test_path / class_name
    
    for img_path in class_folder.glob("*.*"):
        result = model(img_path, verbose=False)[0]
        
        pred_class = result.probs.top1  # predicted index
        
        y_pred.append(pred_class)
        y_true.append(class_id)

# Print metrics
print(classification_report(y_true, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6136    0.7297    0.6667        37
#            1     0.9740    0.9566    0.9653       392
#
#     accuracy                         0.9371       429
#    macro avg     0.7938    0.8432    0.8160       429
# weighted avg     0.9429    0.9371    0.9395       429
